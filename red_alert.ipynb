# %%
import scipy.io.wavfile
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import pyaudio
import wave

samplerate, audio_data = scipy.io.wavfile.read('/home/dfl/Programmierung/esp8266/esp8266-wifi-lightswitch/tng_red_alert1.wav')
channel1, channel2 = list(zip(*audio_data))

width = len(channel1)
plt.plot(range(width), channel1)
plt.show()

plt.plot(range(width), channel2)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/scipy/io/wavfile.py:221: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
1
# Out:
# 1

# %%
print(audio_data)
